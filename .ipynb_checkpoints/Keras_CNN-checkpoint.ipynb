# %% [markdown]
# # Rotate Images

# %%
import numpy
import cv2
from keras import models
from keras.models import load_model
from keras import backend as K
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Bild laden

# %%
file = 'datasets/DevDay/luigi_full.tiff'
im = cv2.imread(file, 0)
plt.figure(figsize=(16, 16))
plt.imshow(im)

# %% [markdown]
# # Keras Model laden

# %%
model = load_model('models/layout_classification/artifacts/text_picture_classifier.h5')
model.summary()  # As a reminder.
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_22 (Conv2D)           (None, 49, 49, 16)        416
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 23, 23, 16)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 7, 7, 32)          12832
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 3, 3, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 288)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1024)              295936
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# ...

# %% [markdown]
# # Testlauf

# %%
shape = (150, 150)
resized = cv2.resize(src=im, dsize=shape, interpolation=cv2.INTER_CUBIC)
normalized = resized / 255.0
reshaped = normalized.reshape((150,150,1))
prediction = model.predict(numpy.asarray([reshaped]))
print "class: %f, prob: %f" % (prediction.argmax(), prediction.max())
# Out:
# class: 0.000000, prob: 0.999996

# %% [markdown]
# # Conv-Layer Activation

# %%
layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(numpy.asarray([reshaped]))

# %% [markdown]
# # Visualize Conv-Layer

# %%
layer_names = []
for layer in model.layers[:4]:
    layer_names.append(layer.name)

images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = numpy.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = numpy.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show()
# Out:
# /Users/markkeinhorster/git/provinzial/Sherlock-Misc/snippets/Mark/sherlock_jupyter/lib/python2.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# # Heatmap for Features

# %%
output = model.output[:, 0]

last_conv_layer = model.get_layer('conv2d_23')

# This is the gradient of the class with regard to
# the output feature map of `conv2d_23`
grads = K.gradients(output, last_conv_layer.output)[0]

# This is a vector of shape (32,), where each entry
# is the mean intensity of the gradient over a specific feature map channel
pooled_grads = K.mean(grads, axis=(0, 1, 2))

# This function allows us to access the values of the quantities we just defined:
# `pooled_grads` and the output feature map of `conv2d_23`,
# given a sample image
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

# These are the values of these two quantities, as Numpy arrays,
# given our sample image of two elephants
pooled_grads_value, conv_layer_output_value = iterate([numpy.asarray([reshaped])])

# We multiply each channel in the feature map array
# by "how important this channel is" with regard to our class
for i in range(32):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

# The channel-wise mean of the resulting feature map
# is our heatmap of class activation
heatmap = numpy.mean(conv_layer_output_value, axis=-1)

heatmap = numpy.maximum(heatmap, 0)
heatmap /= numpy.max(heatmap)
fig = plt.figure(figsize=(12, 12))
plt.matshow(heatmap)
plt.show()

# %%
import cv2

colored = cv2.imread(file)
colored = cv2.cvtColor(colored, cv2.COLOR_BGR2RGB)

# We resize the heatmap to have the same size as the original image
heatmap = cv2.resize(heatmap, (im.shape[1], im.shape[0]))

# We convert the heatmap to RGB
heatmap = numpy.uint8(heatmap * 255)

# We apply the heatmap to the original image
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# 0.4 here is a heatmap intensity factor
superimposed_img = heatmap * 0.1 + colored

fig = plt.figure(figsize=(12, 12))
fig.add_subplot(1, 2, 1)
plt.imshow(colored)

fig.add_subplot(1, 2, 2)
plt.imshow(numpy.uint8(superimposed_img))
